# %%
import pandas as pd  # dataframe operations

import numpy as np   # Math operations

import matplotlib.pyplot as plt  # Diagrams / plots

import seaborn as sns  # Diagrams / plots

# %%
# data set name:  visadataset
# read csv file : comma seperated package
# extension : .csv
# you can read this using pandas package

# read excel file
# extension : .xlsx

# %%
# path 
# file location

# %%
path=r'C:\Users\anilg\Ds naresh it\EDA\Visadataset - Visadataset.csv'
pd.read_csv(path)
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
path=r'C:\Users\anilg\Ds naresh it\EDA\Visadataset - Visadataset.csv'
pd.read_csv(path,header=None)
# Out:
#               0          1                      2                   3   \
# 0        case_id  continent  education_of_employee  has_job_experience
# 1         EZYV01       Asia            High School                   N
# 2         EZYV02       Asia               Master's                   Y
# 3         EZYV03       Asia             Bachelor's                   N
# 4         EZYV04       Asia             Bachelor's                   N
# ...          ...        ...                    ...                 ...
# 25476  EZYV25476       Asia             Bachelor's                   Y
# 25477  EZYV25477       Asia            High School                   Y
# 25478  EZYV25478       Asia               Master's                   Y
# 25479  EZYV25479       Asia               Master's                   Y
# 25480  EZYV25480       Asia             Bachelor's                   Y
#
#                           4                5            6   \
# ...

# %%
path=r'C:\Users\anilg\Ds naresh it\EDA\Visadataset - Visadataset.csv'
pd.read_csv(path)
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# #  create dataframes using list

# %%
name=['Ramesh','Suresh','Sathish']
age=[30,35,40]
name,age
# Out:
# (['Ramesh', 'Suresh', 'Sathish'], [30, 35, 40])

# %%
pd.DataFrame()       # make the dataframe
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
pd.DataFrame(zip(name,age))
# Out:
#          0   1
# 0   Ramesh  30
# 1   Suresh  35
# 2  Sathish  40

# %%
# provide colums

data=zip(name,age)
pd.DataFrame(data,columns=['name','age'])
# Out:
#       name  age
# 0   Ramesh   30
# 1   Suresh   35
# 2  Sathish   40

# %%
# provide index
data=zip(name,age) 
pd.DataFrame(data,columns=['name','age'],index=['A','B','C'])
# Out:
#       name  age
# A   Ramesh   30
# B   Suresh   35
# C  Sathish   40

# %%
# add new column

name=['Ramesh','Suresh','Sathish']
age=[30,35,40]

data=zip(name,age)
df=pd.DataFrame(data,columns=['name','age'],index=['A','B','C'])
df
# Out:
#       name  age
# A   Ramesh   30
# B   Suresh   35
# C  Sathish   40

# %% [markdown]
# - if you want to add a new column
#
# - df['new column']
#
# - you need to have a list which is having some elements
#
# - that elements need to equal to numbers of rows
#
# - city_names=['Hyd','Blr','chennai']
#
# - df['city']=city_names

# %%
city_names=["Hyd","Blr","Chennai"]
df['city']=city_names
df
# Out:
#       name  age     city
# A   Ramesh   30      Hyd
# B   Suresh   35      Blr
# C  Sathish   40  Chennai

# %%
e=df.drop("city",axis=1)
e
# Out:
#       name  age
# A   Ramesh   30
# B   Suresh   35
# C  Sathish   40

# %%
df
# Out:
#       name  age     city
# A   Ramesh   30      Hyd
# B   Suresh   35      Blr
# C  Sathish   40  Chennai

# %% [markdown]
# - update the exsisting column
#
# - if you want to create new column or upadate the old column
#
# - both are same way

# %%
df['name']=['swamy','Asif','Sathwik']
df
# Out:
#       name  age     city
# A    swamy   30      Hyd
# B     Asif   35      Blr
# C  Sathwik   40  Chennai

# %% [markdown]
# # drop the column
#
# - in order to drop the column
#
# - we need to use drop method
#
# - it takes 3 parameters
#
#     - drop column or row
#
#     - mention the column name
#
#     - axis
#
#        - axis=1: reference as column
#
#        - axis=0: reference as row
#
#     - you want to create a new dataframe or
#
#     - you want to over write the exisisting dataframe
#
#        - inplace=True

# %%
df.drop('city',
       axis=1)
# Out:
#       name  age
# A    swamy   30
# B     Asif   35
# C  Sathwik   40

# %%
df
# Out:
#       name  age     city
# A    swamy   30      Hyd
# B     Asif   35      Blr
# C  Sathwik   40  Chennai

# %%
df.drop('C',
       axis=0,
       inplace=True)

# %%
# save the data frame 

df.to_csv("Output.csv")
# df.to_excel("output.xlsx")

# %%
pd.read_csv("Output.csv")
# Out:
#   Unnamed: 0   name  age city
# 0          A  swamy   30  Hyd
# 1          B   Asif   35  Blr

# %% [markdown]
# #### step-10

# %% [markdown]
# $remove-the-index$

# %%
# to aviod the above problem
# give index=Flase

df.to_csv("Output.csv",index=False)

pd.read_csv("Output.csv")
# Out:
#     name  age city
# 0  swamy   30  Hyd
# 1   Asif   35  Blr

# %% [markdown]
# # create dataframes using dictionary

# %%
d1={"names":['Ramesh','Suresh','Sathish'],
   "Age":[30,35,40]}

pd.DataFrame(d1)
# Out:
#      names  Age
# 0   Ramesh   30
# 1   Suresh   35
# 2  Sathish   40

# %%
d1={"names":['Ramesh','Suresh','Sathish'],
   "Age":[30,35,40]}

df=pd.DataFrame(d1)
df
# no need of zip
# no need of column
# Out:
#      names  Age
# 0   Ramesh   30
# 1   Suresh   35
# 2  Sathish   40

# %%
city=["hyd","blr","chennai"]
df['city']=city
df
# Out:
#      names  Age     city
# 0   Ramesh   30      hyd
# 1   Suresh   35      blr
# 2  Sathish   40  chennai

# %%
d2=pd.DataFrame({"City":["hyd","Blr","Chennai"]})

# %%
d2
# Out:
#       City
# 0      hyd
# 1      Blr
# 2  Chennai

# %%
e = pd.concat([df,d2],axis = 1)

# %%
e
# Out:
#      names  Age     city     City
# 0   Ramesh   30      hyd      hyd
# 1   Suresh   35      blr      Blr
# 2  Sathish   40  chennai  Chennai

# %%
pd.DataFrame(d1,index=['A','B','C'])
# Out:
#      names  Age
# A   Ramesh   30
# B   Suresh   35
# C  Sathish   40

# %%
df['names']=['swamy','Asif','Sathwik']
df
# Out:
#      names  Age     city
# 0    swamy   30      hyd
# 1     Asif   35      blr
# 2  Sathwik   40  chennai

# %% [markdown]
# *import the packages*

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path=r'C:\Users\anilg\Ds naresh it\EDA\Visadataset - Visadataset.csv'
pd.read_csv(path)
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
path=r'C:\Users\anilg\Ds naresh it\EDA\Visadataset - Visadataset.csv'
df=pd.read_csv(path)

# %% [markdown]
# $head$

# %% [markdown]
# $top 5 rows$

# %%
#dataframe name: df
df.head()    # by default it consider as 5 rows
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
df.head(2)
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# 1       83425.6500         Year                  Y   Certified

# %% [markdown]
# $tail$

# %% [markdown]
# $last-5-rows$

# %%
df.tail()
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 25475                South         77092.57         Year                  Y
# ...

# %%
df.tail(2)
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 25478                 West         86154.77         Year                  Y
# 25479              Midwest         70876.91         Year                  Y
#
#       case_status
# 25478   Certified
# 25479   Certified

# %% [markdown]
# $shape$

# %% [markdown]
# - number of rows and number of columns

# %%
df.shape
# Out:
# (25480, 12)

# %%
df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
print("the Number of rows :",df.shape[0])
print("the Number of columns :",df.shape[1])
# Out:
# the Number of rows : 25480
# the Number of columns : 12

# %% [markdown]
# $size$

# %% [markdown]
# - how many indices are there provided by size

# %%
df.size
# Out:
# 305760

# %%
25480*12
# Out:
# 305760

# %% [markdown]
# $columns$

# %%
df.columns    # all the column values
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %% [markdown]
# $dtypes$

# %% [markdown]
# **data types**

# %%
df.dtypes

# object means categorical
# other than object is numerical(int or float)
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %%
type(df.dtypes)
# Out:
# pandas.core.series.Series

# %% [markdown]
# $task-1$
#
# **Extract Numerical columns And Categorical columns seperated by using dtypes output**

# %%
dict(df.dtypes)
# Out:
# {'case_id': dtype('O'),
#  'continent': dtype('O'),
#  'education_of_employee': dtype('O'),
#  'has_job_experience': dtype('O'),
#  'requires_job_training': dtype('O'),
#  'no_of_employees': dtype('int64'),
#  'yr_of_estab': dtype('int64'),
#  'region_of_employment': dtype('O'),
#  'prevailing_wage': dtype('float64'),
#  'unit_of_wage': dtype('O'),
#  'full_time_position': dtype('O'),
#  'case_status': dtype('O')}

# %%
a=dict(df.dtypes)
num_val=[]
cate_val=[]
for i in a:
    if a[i]=='object':
         cate_val.append(i)
    else:
        num_val.append(i)
print(cate_val)
print(num_val)
# Out:
# ['case_id', 'continent', 'education_of_employee', 'has_job_experience', 'requires_job_training', 'region_of_employment', 'unit_of_wage', 'full_time_position', 'case_status']
# ['no_of_employees', 'yr_of_estab', 'prevailing_wage']

# %%
d1=dict(df.dtypes)
cat=[i for i in d1 if d1[i]=='object']
num=[i for i in d1 if d1[i]!='object']

# %%
cat
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'region_of_employment',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %%
num
# Out:
# ['no_of_employees', 'yr_of_estab', 'prevailing_wage']

# %%
# categorical data available
df.select_dtypes(include='object').columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
df.select_dtypes(exclude='object').columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
# df has 12 columns
# df.select_dtypes(include='object').columns   has 9 columns
# df.select_dtypes(exclude='object').columns   has 3 columns

# %% [markdown]
# $isnull$
#
# **identify if data has any missing values or null values**

# %%
df.isnull()
# true means  (yes) there is a null values
# flase means (no) theren is no null values
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0        False      False                  False               False
# 1        False      False                  False               False
# 2        False      False                  False               False
# 3        False      False                  False               False
# 4        False      False                  False               False
# ...        ...        ...                    ...                 ...
# 25475    False      False                  False               False
# 25476    False      False                  False               False
# 25477    False      False                  False               False
# 25478    False      False                  False               False
# 25479    False      False                  False               False
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                      False            False        False
# ...

# %%
# when you open excel sheet the data has empty
# which means the data has missed 
#  when you read that using pandas
# at that particular postion it display as null

# %%
df.isnull().sum()
# Out:
# case_id                  0
# continent                0
# education_of_employee    0
# has_job_experience       0
# requires_job_training    0
# no_of_employees          0
# yr_of_estab              0
# region_of_employment     0
# prevailing_wage          0
# unit_of_wage             0
# full_time_position       0
# case_status              0
# dtype: int64

# %% [markdown]
# $ drop $ duplicate
#
# **drop duplicates**

# %%
df.drop_duplicates()
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# $info$

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25480 entries, 0 to 25479
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   case_id                25480 non-null  object
#  1   continent              25480 non-null  object
#  2   education_of_employee  25480 non-null  object
#  3   has_job_experience     25480 non-null  object
#  4   requires_job_training  25480 non-null  object
#  5   no_of_employees        25480 non-null  int64
#  6   yr_of_estab            25480 non-null  int64
#  7   region_of_employment   25480 non-null  object
#  8   prevailing_wage        25480 non-null  float64
#  9   unit_of_wage           25480 non-null  object
#  10  full_time_position     25480 non-null  object
#  11  case_status            25480 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 2.3+ MB

# %%
- head

- tail

- shape

- size

- columns

- dtypes

- isnull

- isnull()sum()

- drop duplicate

- info

- len
# Out:
#   Cell In[70], line 15
#     - isnull()sum()
#               ^
# SyntaxError: invalid syntax

# %% [markdown]
# *bound method*
#      - you need to keep brackets
#
# *not collable*
#      - you need to remove the brackets
#
# *Attribute error*
#      - the method is not available
#      - check the spell mistakes

# %%
# we want to read same sample of data
# we know head will gives top 5
# we know tail will give last 5
# if you want specific rows and columns

# %% [markdown]
# $take-loc-iloc$

# %%
df.take([2,3,4])

#
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 2        122996.86         Year                  Y      Denied
# 3         83434.03         Year                  Y      Denied
# 4        149907.39         Year                  Y   Certified

# %%
df.take([2,3,4],axis=1)
# Out:
#       education_of_employee has_job_experience requires_job_training
# 0               High School                  N                     N
# 1                  Master's                  Y                     N
# 2                Bachelor's                  N                     Y
# 3                Bachelor's                  N                     N
# 4                  Master's                  Y                     N
# ...                     ...                ...                   ...
# 25475            Bachelor's                  Y                     Y
# 25476           High School                  Y                     N
# 25477              Master's                  Y                     N
# 25478              Master's                  Y                     Y
# 25479            Bachelor's                  Y                     N
#
# [25480 rows x 3 columns]

# %%
df.take([100,200,400]).take([4,8,11],axis=1)
# Out:
#     requires_job_training  prevailing_wage case_status
# 100                     N         28243.79   Certified
# 200                     N         74441.11   Certified
# 400                     N        113927.99   Certified

# %% [markdown]
# *take does not take rows and columns at a time*

# %% [markdown]
# $iloc$

# %%
df.iloc[<rows>,<columns>]
df.iloc[<start:end>,<start:end>]

rows=[]
columns=[]
df.iloc[rows,columns]
# Out:
#   Cell In[75], line 1
#     df.iloc[<rows>,<columns>]
#             ^
# SyntaxError: invalid syntax

# %%
df.iloc[5:10]
# Out:
#   case_id      continent education_of_employee has_job_experience  \
# 5  EZYV06           Asia              Master's                  Y
# 6  EZYV07           Asia            Bachelor's                  N
# 7  EZYV08  North America            Bachelor's                  Y
# 8  EZYV09           Asia            Bachelor's                  N
# 9  EZYV10         Europe             Doctorate                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 5                     N             2339         2012                South
# 6                     N             4985         1994                South
# 7                     N             3035         1924                 West
# 8                     N             4810         2012              Midwest
# 9                     N             2251         1995                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# ...

# %%
df.iloc[5:10,2:5]
# Out:
#   education_of_employee has_job_experience requires_job_training
# 5              Master's                  Y                     N
# 6            Bachelor's                  N                     N
# 7            Bachelor's                  Y                     N
# 8            Bachelor's                  N                     N
# 9             Doctorate                  Y                     N

# %%
df.iloc[:,2:5]
# Out:
#       education_of_employee has_job_experience requires_job_training
# 0               High School                  N                     N
# 1                  Master's                  Y                     N
# 2                Bachelor's                  N                     Y
# 3                Bachelor's                  N                     N
# 4                  Master's                  Y                     N
# ...                     ...                ...                   ...
# 25475            Bachelor's                  Y                     Y
# 25476           High School                  Y                     N
# 25477              Master's                  Y                     N
# 25478              Master's                  Y                     Y
# 25479            Bachelor's                  Y                     N
#
# [25480 rows x 3 columns]

# %%
rows=[100,200,300]
columns=[4,8,11]
df.iloc[rows,columns]
# Out:
#     requires_job_training  prevailing_wage case_status
# 100                     N         28243.79   Certified
# 200                     N         74441.11   Certified
# 300                     N        101371.21   Certified

# %%
# only prevailing_wage
df.iloc[[100,200,300],[8]]

# no bracket : series
# bracket is there : data frame
# Out:
#      prevailing_wage
# 100         28243.79
# 200         74441.11
# 300        101371.21

# %% [markdown]
# $loc$

# %%
df.loc[[100,200,300],['full_time_position' ]]
# Out:
#     full_time_position
# 100                  Y
# 200                  Y
# 300                  Y

# %%
df.loc[[100,200,300],[10]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 df.loc[[100,200,300],[10]]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1097, in _LocationIndexer.__getitem__(self, key)
#    1095     if self._is_scalar_access(key):
#    1096         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1097     return self._getitem_tuple(key)
#    1098 else:
#    1099     # we by definition only have the 0th axis
#    1100     axis = self.axis or 0
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1287, in _LocIndexer._getitem_tuple(self, tup)
#    1285 # ugly hack for GH #836
#    1286 if self._multi_take_opportunity(tup):
# -> 1287     return self._multi_take(tup)
#    1289 return self._getitem_tuple_same_dim(tup)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1238, in _LocIndexer._multi_take(self, tup)
# ...
