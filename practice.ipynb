# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path=r'C:\Users\anilg\Ds naresh it\EDA\Visadataset - Visadataset.csv'
visa_df=pd.read_csv(path)
visa_df.head(3)
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# 1       83425.6500         Year                  Y   Certified
# 2      122996.8600         Year                  Y      Denied

# %%
visa_df['education_of_employee']
# Out:
# 0        High School
# 1           Master's
# 2         Bachelor's
# 3         Bachelor's
# 4           Master's
#             ...
# 25475     Bachelor's
# 25476    High School
# 25477       Master's
# 25478       Master's
# 25479     Bachelor's
# Name: education_of_employee, Length: 25480, dtype: object

# %%
visa_df[['education_of_employee']]
# Out:
#       education_of_employee
# 0               High School
# 1                  Master's
# 2                Bachelor's
# 3                Bachelor's
# 4                  Master's
# ...                     ...
# 25475            Bachelor's
# 25476           High School
# 25477              Master's
# 25478              Master's
# 25479            Bachelor's
#
# [25480 rows x 1 columns]

# %%
visa_df.education_of_employee
# Out:
# 0        High School
# 1           Master's
# 2         Bachelor's
# 3         Bachelor's
# 4           Master's
#             ...
# 25475     Bachelor's
# 25476    High School
# 25477       Master's
# 25478       Master's
# 25479     Bachelor's
# Name: education_of_employee, Length: 25480, dtype: object

# %%
visa_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
col=['case_id','education_of_employee']
visa_df[col]
# Out:
#          case_id education_of_employee
# 0         EZYV01           High School
# 1         EZYV02              Master's
# 2         EZYV03            Bachelor's
# 3         EZYV04            Bachelor's
# 4         EZYV05              Master's
# ...          ...                   ...
# 25475  EZYV25476            Bachelor's
# 25476  EZYV25477           High School
# 25477  EZYV25478              Master's
# 25478  EZYV25479              Master's
# 25479  EZYV25480            Bachelor's
#
# [25480 rows x 2 columns]

# %%
visa_df.values
# Out:
# array([['EZYV01', 'Asia', 'High School', ..., 'Hour', 'Y', 'Denied'],
#        ['EZYV02', 'Asia', "Master's", ..., 'Year', 'Y', 'Certified'],
#        ['EZYV03', 'Asia', "Bachelor's", ..., 'Year', 'Y', 'Denied'],
#        ...,
#        ['EZYV25478', 'Asia', "Master's", ..., 'Year', 'N', 'Certified'],
#        ['EZYV25479', 'Asia', "Master's", ..., 'Year', 'Y', 'Certified'],
#        ['EZYV25480', 'Asia', "Bachelor's", ..., 'Year', 'Y', 'Certified']],
#       dtype=object)

# %%
visa_df['education_of_employee']
# Out:
# 0        High School
# 1           Master's
# 2         Bachelor's
# 3         Bachelor's
# 4           Master's
#             ...
# 25475     Bachelor's
# 25476    High School
# 25477       Master's
# 25478       Master's
# 25479     Bachelor's
# Name: education_of_employee, Length: 25480, dtype: object

# %%
visa_df['education_of_employee'].unique()
# Out:
# array(['High School', "Master's", "Bachelor's", 'Doctorate'], dtype=object)

# %%
visa_df['education_of_employee'].values
# Out:
# array(['High School', "Master's", "Bachelor's", ..., "Master's",
#        "Master's", "Bachelor's"], dtype=object)

# %%
set(visa_df['education_of_employee'].values)
# Out:
# {"Bachelor's", 'Doctorate', 'High School', "Master's"}

# %%
list(set(visa_df['education_of_employee'].values))
# Out:
# ["Bachelor's", 'High School', 'Doctorate', "Master's"]

# %%
visa_df['education_of_employee'].nunique()
# Out:
# 4

# %%
visa_df['education_of_employee']=="Bachelor's"
# Out:
# 0        False
# 1        False
# 2         True
# 3         True
# 4        False
#          ...
# 25475     True
# 25476    False
# 25477    False
# 25478    False
# 25479     True
# Name: education_of_employee, Length: 25480, dtype: bool

# %%
con=visa_df['education_of_employee']=="Bachelor's"
visa_df[con]
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 2         EZYV03           Asia            Bachelor's                  N
# 3         EZYV04           Asia            Bachelor's                  N
# 6         EZYV07           Asia            Bachelor's                  N
# 7         EZYV08  North America            Bachelor's                  Y
# 8         EZYV09           Asia            Bachelor's                  N
# ...          ...            ...                   ...                ...
# 25466  EZYV25467         Europe            Bachelor's                  Y
# 25468  EZYV25469           Asia            Bachelor's                  N
# 25473  EZYV25474           Asia            Bachelor's                  Y
# 25475  EZYV25476           Asia            Bachelor's                  Y
# 25479  EZYV25480           Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
len(visa_df[con])
# Out:
# 10234

# %%
visa_df['continent'].unique()
# Out:
# array(['Asia', 'Africa', 'North America', 'Europe', 'South America',
#        'Oceania'], dtype=object)

# %%
con=visa_df[(visa_df['education_of_employee']=="Master's") & (visa_df['continent']=="Asia")]
con
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 1         EZYV02      Asia              Master's                  Y
# 5         EZYV06      Asia              Master's                  Y
# 10        EZYV11      Asia              Master's                  N
# 14        EZYV15      Asia              Master's                  Y
# 17        EZYV18      Asia              Master's                  Y
# ...          ...       ...                   ...                ...
# 25458  EZYV25459      Asia              Master's                  Y
# 25461  EZYV25462      Asia              Master's                  Y
# 25464  EZYV25465      Asia              Master's                  N
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 1                         N             2412         2002
# ...

# %%
com=visa_df[(visa_df["education_of_employee"]=="Bachelor's")&(visa_df["continent"]=="Asia")]
len(com)
# Out:
# 7168

# %%
com=visa_df[(visa_df["education_of_employee"]=="Bachelor's")&(visa_df["continent"]=="Asia")]
com
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 6         EZYV07      Asia            Bachelor's                  N
# 8         EZYV09      Asia            Bachelor's                  N
# 12        EZYV13      Asia            Bachelor's                  Y
# ...          ...       ...                   ...                ...
# 25456  EZYV25457      Asia            Bachelor's                  Y
# 25468  EZYV25469      Asia            Bachelor's                  N
# 25473  EZYV25474      Asia            Bachelor's                  Y
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 2                         Y            44444         2008
# ...

# %%
com=visa_df[(visa_df["education_of_employee"]=="Bachelor's")&(visa_df["continent"]=="Asia")&(visa_df["has_job_experience"]=='N')]
com
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 6         EZYV07      Asia            Bachelor's                  N
# 8         EZYV09      Asia            Bachelor's                  N
# 32        EZYV33      Asia            Bachelor's                  N
# ...          ...       ...                   ...                ...
# 25439  EZYV25440      Asia            Bachelor's                  N
# 25442  EZYV25443      Asia            Bachelor's                  N
# 25450  EZYV25451      Asia            Bachelor's                  N
# 25454  EZYV25455      Asia            Bachelor's                  N
# 25468  EZYV25469      Asia            Bachelor's                  N
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 2                         Y            44444         2008
# ...

# %%
len(com)
# Out:
# 3033

# %%
visa_df['education_of_employee'].nunique()
# Out:
# 4

# %%
unique_Degree=visa_df["education_of_employee"].unique()
for i in unique_Degree:
    con=visa_df['education_of_employee']==i
    print(i,":",len(visa_df[con]))
# Out:
# High School : 3420
# Master's : 9634
# Bachelor's : 10234
# Doctorate : 2192

# %%
unique_Degree=visa_df["education_of_employee"].unique()
count=[]
for i in unique_Degree:
    con=visa_df['education_of_employee']==i
    count.append(len(visa_df[con]))
count
# Out:
# [3420, 9634, 10234, 2192]

# %%
visa_vc_df=pd.DataFrame(zip(unique_Degree,count),columns=['continent','count'])

# %%
plt.bar('continent','count',data=visa_vc_df)
plt.xlabel("education_of_employee")
plt.ylabel('count')
plt.title("frequency of education qualification of employees")
plt.show()

# %%
path=r'C:\Users\anilg\Ds naresh it\EDA\Visadataset - Visadataset.csv'
visa_df=pd.read_csv(path)

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df.head(4)
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# 1       83425.6500         Year                  Y   Certified
# 2      122996.8600         Year                  Y      Denied
# ...

# %%
visa_df.head(4).tail(2)
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 2        122996.86         Year                  Y      Denied
# 3         83434.03         Year                  Y      Denied

# %%
visa_df.tail(10).head(5)
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 25470  EZYV25471  North America              Master's                  Y
# 25471  EZYV25472           Asia           High School                  N
# 25472  EZYV25473           Asia           High School                  N
# 25473  EZYV25474           Asia            Bachelor's                  Y
# 25474  EZYV25475         Africa             Doctorate                  N
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25470                     N             2272         1970
# 25471                     N            40224         1962
# 25472                     N             1346         2003
# 25473                     N             2421         2007
# 25474                     N             2594         1979
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 25470            Northeast         516.4101         Hour                  Y
# ...

# %%
visa_df.shape
# Out:
# (25480, 12)

# %%
visa_df.size
# Out:
# 305760

# %%
25480*12
# Out:
# 305760

# %%
set(visa_df['continent'])
# Out:
# {'Africa', 'Asia', 'Europe', 'North America', 'Oceania', 'South America'}

# %%
con=visa_df['continent']=='Asia'
visa_df[con]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 5         EZYV06      Asia              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
con=(visa_df["continent"]=="Asia")&(visa_df["education_of_employee"]=="Master's")
visa_df[con]
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 1         EZYV02      Asia              Master's                  Y
# 5         EZYV06      Asia              Master's                  Y
# 10        EZYV11      Asia              Master's                  N
# 14        EZYV15      Asia              Master's                  Y
# 17        EZYV18      Asia              Master's                  Y
# ...          ...       ...                   ...                ...
# 25458  EZYV25459      Asia              Master's                  Y
# 25461  EZYV25462      Asia              Master's                  Y
# 25464  EZYV25465      Asia              Master's                  N
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 1                         N             2412         2002
# ...

# %%
visa_asia=visa_df[con]

# %%
visa_asia.loc[:,["prevailing_wage","education_of_employee","case_id"]]
# Out:
#        prevailing_wage education_of_employee    case_id
# 1           83425.6500              Master's     EZYV02
# 5           78252.1400              Master's     EZYV06
# 10          83588.5600              Master's     EZYV11
# 14         220081.7300              Master's     EZYV15
# 17          16132.6100              Master's     EZYV18
# ...                ...                   ...        ...
# 25458       81497.1900              Master's  EZYV25459
# 25461          54.9196              Master's  EZYV25462
# 25464      145102.3600              Master's  EZYV25465
# 25477      146298.8500              Master's  EZYV25478
# 25478       86154.7700              Master's  EZYV25479
#
# [6480 rows x 3 columns]

# %%
visa_df["prevailing_wage"].mean()
# Out:
# 74455.81459209183

# %%
np.mean(visa_df['prevailing_wage'])
# Out:
# 74455.81459209183

# %%
np.median(visa_df['prevailing_wage'])
# Out:
# 70308.20999999999

# %%
np.max(visa_df['prevailing_wage'])
# Out:
# 319210.27

# %%
np.min(visa_df["prevailing_wage"])
# Out:
# 2.1367

# %%
np.std(visa_df['prevailing_wage'])
# Out:
# 52814.90589711402

# %%
a=round(np.mean(visa_df["prevailing_wage"]),2)
b=round(np.median(visa_df["prevailing_wage"]),2)
c=round(np.max(visa_df["prevailing_wage"]),2)
d=round(np.min(visa_df["prevailing_wage"]),2)
e=round(np.std(visa_df["prevailing_wage"]),2)
l=[a,b,c,d,e]
pd.DataFrame(l,columns=["prevailing_wage"],index=["mean","median","max","min","std"])
# Out:
#         prevailing_wage
# mean           74455.81
# median         70308.21
# max           319210.27
# min                2.14
# std            52814.91

# %%
a=round(np.mean(visa_df["prevailing_wage"]),2)
b=round(np.median(visa_df["prevailing_wage"]),2)
c=round(np.max(visa_df["prevailing_wage"]),2)
d=round(np.min(visa_df["prevailing_wage"]),2)
e=round(np.std(visa_df["prevailing_wage"]),2)
f=round(np.percentile(visa_df["prevailing_wage"],25),2)
g=round(np.percentile(visa_df["prevailing_wage"],50),2)
h=round(np.percentile(visa_df["prevailing_wage"],75),2)
l=[a,b,c,d,e,f,g,h]
data1=pd.DataFrame(l,columns=["prevailing_wage"],index=["mean","median","max","min","std","25%","50%","75%"])

# %%
data1
# Out:
#         prevailing_wage
# mean           74455.81
# median         70308.21
# max           319210.27
# min                2.14
# std            52814.91
# 25%            34015.48
# 50%            70308.21
# 75%           107735.51

# %%
np.mean(visa_asia['prevailing_wage'])
# Out:
# 83172.54042469137

# %%
np.median(visa_asia["prevailing_wage"])
# Out:
# 80132.525

# %%
visa_asia.describe()
# Out:
#        no_of_employees  yr_of_estab  prevailing_wage
# count      6480.000000  6480.000000      6480.000000
# mean       6124.748920  1980.038426     83172.540425
# std       25172.383312    42.012271     54471.299762
# min         -26.000000  1800.000000         3.318800
# 25%        1043.000000  1977.000000     43493.382500
# 50%        2131.000000  1997.500000     80132.525000
# 75%        3548.500000  2005.000000    117039.315000
# max      581468.000000  2016.000000    318446.050000

# %%
cols=visa_df.select_dtypes(exclude='object').columns
l=[]
for i in cols:
    countt=round(visa_df[i].count(),2)
    mean=round(np.mean(visa_df[i]),2)
    stdd=round(np.std(visa_df[i]),2)
    maxx=round(np.max(visa_df[i]),2)
    median=round(np.median(visa_df[i]),2)
    wage_25=round(np.percentile(visa_df[i],25),2)
    wage_50=round(np.percentile(visa_df[i],50),2)
    wage_75=round(np.percentile(visa_df[i],75),2)
    minn=round(np.min(visa_df[i]),2)
    l.append([countt,mean,stdd,maxx,median,wage_25,wage_50,wage_75,minn])
index=["count","mean","stdd","maxx","medain","25%","50%","75%",'min']
pd.DataFrame(zip(l[0],l[1],l[2]),columns=cols,index=index)
# Out:
#         no_of_employees  yr_of_estab  prevailing_wage
# count          25480.00     25480.00         25480.00
# mean            5667.04      1979.41         74455.81
# stdd           22877.48        42.37         52814.91
# maxx          602069.00      2016.00        319210.27
# medain          2109.00      1997.00         70308.21
# 25%             1022.00      1976.00         34015.48
# 50%             2109.00      1997.00         70308.21
# 75%             3504.00      2005.00        107735.51
# min              -26.00      1800.00             2.14

# %%
cols=visa_df.select_dtypes(exclude="object").columns
cols
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
visa_df.head(3)
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# 1       83425.6500         Year                  Y   Certified
# 2      122996.8600         Year                  Y      Denied

# %%
Q1=np.percentile(visa_df['yr_of_estab'],25)
Q2=np.percentile(visa_df['yr_of_estab'],50)
Q3=np.percentile(visa_df['yr_of_estab'],75)
IQR=Q3-Q1
lb=Q1-(1.5*IQR)
ub=Q3+(1.5*IQR)
c1=visa_df['yr_of_estab']<lb
c2=visa_df['yr_of_estab']>ub
c=c1|c2
visa_df_outliers=visa_df[c]
visa_df_outliers
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 3         EZYV04           Asia            Bachelor's                  N
# 7         EZYV08  North America            Bachelor's                  Y
# 23        EZYV24  North America           High School                  N
# 31        EZYV32           Asia             Doctorate                  Y
# 38        EZYV39           Asia            Bachelor's                  Y
# ...          ...            ...                   ...                ...
# 25445  EZYV25446           Asia            Bachelor's                  Y
# 25463  EZYV25464           Asia           High School                  N
# 25467  EZYV25468  North America              Master's                  N
# 25477  EZYV25478           Asia              Master's                  Y
# 25478  EZYV25479           Asia              Master's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
Q1=np.percentile(visa_df['yr_of_estab'],25)
Q2=np.percentile(visa_df['yr_of_estab'],50)
Q3=np.percentile(visa_df['yr_of_estab'],75)
IQR=Q3-Q1
lb=Q1-(1.5*IQR)
ub=Q3+(1.5*IQR)
c1=visa_df['yr_of_estab']>lb
c2=visa_df['yr_of_estab']<ub
c=c1&c2
visa_df_non_outliers=visa_df[c]
visa_df_non_outliers,
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# 5         EZYV06      Asia              Master's                  Y
# ...          ...       ...                   ...                ...
# 25473  EZYV25474      Asia            Bachelor's                  Y
# 25474  EZYV25475    Africa             Doctorate                  N
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...
