# %% [markdown]
# ### Data Transformation Techniques

# %% [markdown]
# - Generally used  for to convert Normal distribution
#
# - Because all statistical math analysis by assumption Data follows Normal distribution
#
# - it is also avoid skew ness also
#
# - We have some important transformation
#
#     - Log transformation
#
#     - Exponential transformation
#
#     - Reciprocal transformation
#
#     - Square root transformation
#
#     - Power transformation

# %% [markdown]
# $step-1$

# %% [markdown]
# **Read the required packages**

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# $step-2$

# %% [markdown]
# **Read the data**

# %% [markdown]
# $Exponential-data$

# %%
exp_data=np.random.exponential(size=10000)
exp_data[:10]

# we are consider exponential data set with random 10k observations
# using numpy package
# Out:
# array([1.90718857, 2.78629443, 0.68787594, 0.78980956, 1.30175243,
#        1.03503593, 0.0538041 , 0.999102  , 0.6699274 , 0.73003986])

# %%
exp_data=np.random.exponential(size=9)
exp_data[:11]
# Out:
# array([0.15503843, 0.35293593, 0.81084161, 1.42409368, 0.30722979,
#        0.03825997, 1.15276902, 0.96992923, 1.6998201 ])

# %%
plt.hist(exp_data,bins=30,label='Exponential')
plt.legend()
plt.show()

# %% [markdown]
# $normal-data$

# %%
norm_data=np.random.normal(size=1000)
plt.hist(norm_data)
# Out:
# (array([ 10.,  27., 107., 189., 264., 229., 116.,  42.,  12.,   4.]),
#  array([-3.05225713, -2.38229374, -1.71233035, -1.04236696, -0.37240357,
#          0.29755982,  0.96752321,  1.6374866 ,  2.30744999,  2.97741338,
#          3.64737677]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# $step-3$

# %% [markdown]
# **Log Transformation**

# %% [markdown]
# - np.log is used for log transformation
#
# - Generally log transformation will not convert data into normal
#
# - it avoids skew ness
#
# - np.log means natural logorithm base=e

# %%
x=2
import numpy as np
np.log(2)
# Out:
# 0.6931471805599453

# %%
log_data=np.log(exp_data)
log_data[:10]
# Out:
# array([ 6.45630204e-01,  1.02471255e+00, -3.74146775e-01, -2.35963429e-01,
#         2.63711379e-01,  3.44361398e-02, -2.92240552e+00, -8.98403404e-04,
#        -4.00585924e-01, -3.14656137e-01])

# %%
exp_data[:10]
# Out:
# array([1.90718857, 2.78629443, 0.68787594, 0.78980956, 1.30175243,
#        1.03503593, 0.0538041 , 0.999102  , 0.6699274 , 0.73003986])

# %%
plt.hist(log_data,bins=40,label='Log data')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1).hist(exp_data,
                        bins=40,
                        label='Exponential')
plt.legend()
plt.subplot(1,2,2).hist(log_data,
                       bins=40,
                       label='Log Transformation')
plt.legend()
plt.show()

# %% [markdown]
# $step-4$

# %% [markdown]
# **Reciprocal transformation**

# %% [markdown]
# - Reciprocal transformation fails when data has zero values

# %%
# Take the exponential data
# rec_data= 1/exp_data
# plot the histogram and check it

# %%
x=3
np.reciprocal(x)
# Out:
# 0

# %%
rec_data=np.reciprocal(exp_data)
plt.hist(rec_data,bins=40,label='Reciprocal data')
plt.legend()
plt.show()

# %%
exp_data,rec_data
# Out:
# (array([1.90718857, 2.78629443, 0.68787594, ..., 0.71622161, 2.60258933,
#         1.00845885]),
#  array([0.524332  , 0.35889962, 1.45375051, ..., 1.39621589, 0.38423273,
#         0.99161211]))

# %%
1/1.90718857
# Out:
# 0.5243320014234355

# %%
exp_data[:2]
# Out:
# array([1.90718857, 2.78629443])

# %% [markdown]
# $step-5$

# %% [markdown]
# **Square root transformation**

# %%
print(25**2)   # Square
print(25**(1/2)) # square root
print(np.sqrt(25))
# Out:
# 625
# 5.0
# 5.0

# %%
sqrt_data=np.sqrt(exp_data)

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1).hist(exp_data,
                       bins=40,
                       label='Exponential')
plt.legend()
plt.subplot(1,2,2).hist(sqrt_data,
                       bins=40,
                       label='Square root Transformation')
plt.legend()
plt.show()

# %%
import seaborn as sns
sns.displot(sqrt_data)
# Out:
# C:\Users\anilg\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# $Step-6$

# %% [markdown]
# **Power Transformer**
#
# - it is related to sklearn package
#
# - package name: sklearn preprocessing
#
# - method name : Power Transformer
#
# - inside Box-Cox , yeo-jhonson

# %%
exp_data
# Out:
# array([1.90718857, 2.78629443, 0.68787594, ..., 0.71622161, 2.60258933,
#        1.00845885])

# %%
from sklearn.preprocessing import PowerTransformer
pt=PowerTransformer()
pt_data=pt.fit([exp_data]).transform([exp_data])

# %%
pt_data
# Out:
# array([[0.00000000e+00, 0.00000000e+00, 1.11022302e-16, ...,
#         0.00000000e+00, 0.00000000e+00, 2.22044605e-16]])

# %%
plt.hist(pt_data[0])
plt.show()
