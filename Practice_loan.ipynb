# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path=path=r'C:\Users\anilg\Ds naresh it\EDA\train_ctrUa4K - train_ctrUa4K.csv'
loan_df=pd.read_csv(path)
loan_df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
loan_df.head(3)
# Out:
#     Loan_ID Gender Married Dependents Education Self_Employed  \
# 0  LP001002   Male      No          0  Graduate            No
# 1  LP001003   Male     Yes          1  Graduate            No
# 2  LP001005   Male     Yes          0  Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y

# %%
loan_df.tail(5)
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# ...

# %%
loan_df.isnull()
# Out:
#      Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0      False   False    False       False      False          False
# 1      False   False    False       False      False          False
# 2      False   False    False       False      False          False
# 3      False   False    False       False      False          False
# 4      False   False    False       False      False          False
# ..       ...     ...      ...         ...        ...            ...
# 609    False   False    False       False      False          False
# 610    False   False    False       False      False          False
# 611    False   False    False       False      False          False
# 612    False   False    False       False      False          False
# 613    False   False    False       False      False          False
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0              False              False        True             False
# ...

# %%
loan_df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
loan_df['Married']
# Out:
# 0       No
# 1      Yes
# 2      Yes
# 3      Yes
# 4       No
#       ...
# 609     No
# 610    Yes
# 611    Yes
# 612    Yes
# 613     No
# Name: Married, Length: 614, dtype: object

# %%
loan_df[['Married']]
# Out:
#     Married
# 0        No
# 1       Yes
# 2       Yes
# 3       Yes
# 4        No
# ..      ...
# 609      No
# 610     Yes
# 611     Yes
# 612     Yes
# 613      No
#
# [614 rows x 1 columns]

# %%
loan_df['Married'].isnull().sum()
# Out:
# 3

# %%
c=loan_df['Married'].isnull()==True
loan_df[c]
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 104  LP001357    Male     NaN        NaN  Graduate            No
# 228  LP001760    Male     NaN        NaN  Graduate            No
# 435  LP002393  Female     NaN        NaN  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 104             3816              754.0       160.0             360.0
# 228             4758                0.0       158.0             480.0
# 435            10047                0.0         NaN             240.0
#
#      Credit_History Property_Area Loan_Status
# 104             1.0         Urban           Y
# 228             1.0     Semiurban           Y
# 435             1.0     Semiurban           Y

# %%
d=loan_df['Married'].isnull()==False
loan_df[d]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
loan_df.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
loan_df['Dependents'].replace({'3+':3},inplace=True)

# %%
loan_df.head(10)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
# 5  LP001011   Male     Yes          2      Graduate           Yes
# 6  LP001013   Male     Yes          0  Not Graduate            No
# 7  LP001014   Male     Yes          3      Graduate            No
# 8  LP001018   Male     Yes          2      Graduate            No
# 9  LP001020   Male     Yes          1      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# ...

# %%
loan_df.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
loan_df=loan_df.fillna(method='bfill')
loan_df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes          3      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
loan_df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
loan_df['Dependents']=loan_df['Dependents'].astype(int)

# %%
loan_df
# Out:
#       Loan_ID  Gender Married  Dependents     Education Self_Employed  \
# 0    LP001002    Male      No           0      Graduate            No
# 1    LP001003    Male     Yes           1      Graduate            No
# 2    LP001005    Male     Yes           0      Graduate           Yes
# 3    LP001006    Male     Yes           0  Not Graduate            No
# 4    LP001008    Male      No           0      Graduate            No
# ..        ...     ...     ...         ...           ...           ...
# 609  LP002978  Female      No           0      Graduate            No
# 610  LP002979    Male     Yes           3      Graduate            No
# 611  LP002983    Male     Yes           1      Graduate            No
# 612  LP002984    Male     Yes           2      Graduate            No
# 613  LP002990  Female      No           0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
loan_df.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents             int32
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
path=path=r'C:\Users\anilg\Ds naresh it\EDA\train_ctrUa4K - train_ctrUa4K.csv'
loan_df=pd.read_csv(path)
loan_df.head(3)
# Out:
#     Loan_ID Gender Married Dependents Education Self_Employed  \
# 0  LP001002   Male      No          0  Graduate            No
# 1  LP001003   Male     Yes          1  Graduate            No
# 2  LP001005   Male     Yes          0  Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y

# %%
d=dict(loan_df.dtypes)
cat_cols=[i for i in d if d[i]=='object']
cat_cols
# Out:
# ['Loan_ID',
#  'Gender',
#  'Married',
#  'Dependents',
#  'Education',
#  'Self_Employed',
#  'Property_Area',
#  'Loan_Status']

# %%
num_cols=[i for i in d if d[i]!='object' ]
num_cols
# Out:
# ['ApplicantIncome',
#  'CoapplicantIncome',
#  'LoanAmount',
#  'Loan_Amount_Term',
#  'Credit_History']

# %%
loan_df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
loan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
loan_df.drop_duplicates()
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
loan_df['Dependents'].replace({'3+':3},inplace=True)
loan_df.head(10)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
# 5  LP001011   Male     Yes          2      Graduate           Yes
# 6  LP001013   Male     Yes          0  Not Graduate            No
# 7  LP001014   Male     Yes          3      Graduate            No
# 8  LP001018   Male     Yes          2      Graduate            No
# 9  LP001020   Male     Yes          1      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# ...

# %%
loan_bfill_df=loan_df.fillna(method='bfill')
loan_bfill_df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes          3      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
loan_bfill_df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
loan_ffill_df=loan_df.fillna(method='ffill')
loan_ffill_df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes          3      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
loan_ffill_df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           1
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
loan_df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
loan_pad_df=loan_df.fillna(method='pad')
loan_pad_df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes          3      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
loan_df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
loan_backfill_df=loan_df.fillna(method='backfill')
loan_backfill_df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes          3      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
loan_backfill_df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
Gender_mode=loan_df['LoanAmount'].mode()

# %%
loan_df['LoanAmount'].fillna(Gender_mode)
# Out:
# 0      120.0
# 1      128.0
# 2       66.0
# 3      120.0
# 4      141.0
#        ...
# 609     71.0
# 610     40.0
# 611    253.0
# 612    187.0
# 613    133.0
# Name: LoanAmount, Length: 614, dtype: float64

# %%
loan_df['LoanAmount'].isnull().sum()
# Out:
# 22

# %%
loan_mean=loan_df['LoanAmount'].mean()
loan_df['LoanAmount']=loan_df['LoanAmount'].fillna(loan_mean)

# %%
loan_df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
loan_df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
Gender_mode=loan_df['Gender'].mode()
loan_df['Gender']=loan_df['Gender'].fillna(Gender_mode)

# %%
Gender_mode
# Out:
# 0    Male
# Name: Gender, dtype: object

# %%
loan_df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
loan_df['Gender']=loan_df['Gender'].fillna(method='bfill')
loan_df.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
loan_df['Married']=loan_df['Married'].fillna(method='pad')

# %%
loan_df.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
loan_df.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
mode_depend=loan_df['Dependents'].mode()
loan_df['Dependents']=loan_df['Dependents'].fillna(method='pad')

# %%
loan_df.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
mode_depend
# Out:
# 0    0
# Name: Dependents, dtype: object

# %%
loan_df.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
loan_df['Self_Employed']=loan_df['Self_Employed'].fillna('No')

# %%
loan_df.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
loan_df.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %%
loan_mode=loan_df['Loan_Amount_Term'].mode()[0]
loan_df['Loan_Amount_Term']=loan_df['Loan_Amount_Term'].fillna(loan_mode)

# %%
loan_df.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      0
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
cred=loan_df['Credit_History'].mean()
loan_df['Credit_History']=loan_df['Credit_History'].fillna(cred)

# %%
loan_df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
d=dict(loan_df.dtypes)
cat_cols=[i for i in d if d[i]=='object']
num_cols=[i for i in d if d[i]!='object']
print("categorical columns are : ",cat_cols)
print("numerical columns are : ",num_cols)
# Out:
# categorical columns are :  ['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education', 'Self_Employed', 'Property_Area', 'Loan_Status']
# numerical columns are :  ['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term', 'Credit_History']

# %%
loan_cat_df=loan_df[cat_cols]

# %%
loan_cat_df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes          3      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#     Property_Area Loan_Status
# 0           Urban           Y
# 1           Rural           N
# 2           Urban           Y
# ...

# %%
d=dict(loan_cat_df.dtypes)

# %%
cat_cols=[i for i in d if d[i]=='object']
cat_cols
# Out:
# ['Loan_ID',
#  'Gender',
#  'Married',
#  'Dependents',
#  'Education',
#  'Self_Employed',
#  'Property_Area',
#  'Loan_Status']

# %%
l=[]
for i in cat_cols[1:]:
    label=loan_df[i].unique()
    for j in range(len(label)):
        c=loan_df[i]==j
    l.append(len(loan_df[c]))
l
# Out:
# [0, 0, 51, 0, 0, 0, 0]

# %%
l
# Out:
# [0, 0, 51, 0, 0, 0, 0]

# %%
cat_cols
# Out:
# ['Loan_ID',
#  'Gender',
#  'Married',
#  'Dependents',
#  'Education',
#  'Self_Employed',
#  'Property_Area',
#  'Loan_Status']

# %%
count=[]
for i in cat_cols[1:]:
    unique_label=loan_df[i].unique()
    for j in unique_label:
        con=loan_df[i]==j
    count.append(len(loan_df[con]))
    print(loan_df[con])
count
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 17   LP001036  Female      No          0      Graduate            No
# 29   LP001087  Female      No          2      Graduate            No
# 37   LP001112  Female     Yes          0      Graduate            No
# 45   LP001137  Female      No          0      Graduate            No
# 48   LP001146  Female     Yes          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 587  LP002917  Female      No          0  Not Graduate            No
# 600  LP002949  Female      No          3      Graduate            No
# 604  LP002959  Female     Yes          1      Graduate            No
# 609  LP002978  Female      No          0      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
loan_df['Property_Area']
# Out:
# 0          Urban
# 1          Rural
# 2          Urban
# 3          Urban
# 4          Urban
#          ...
# 609        Rural
# 610        Rural
# 611        Urban
# 612        Urban
# 613    Semiurban
# Name: Property_Area, Length: 614, dtype: object

# %%
loan_df['Property_Area'].value_counts()
# Out:
# Property_Area
# Semiurban    233
# Urban        202
# Rural        179
# Name: count, dtype: int64

# %%
loan_df['Property_Area'].value_counts().values
# Out:
# array([233, 202, 179], dtype=int64)

# %%
loan_df['Property_Area'].value_counts().keys()
# Out:
# Index(['Semiurban', 'Urban', 'Rural'], dtype='object', name='Property_Area')

# %%
unique_label=loan_df['Property_Area'].unique()
count=[]
for i in unique_label:
    c=loan_df['Property_Area']==i
    count.append(len(loan_df[c]))
count
# Out:
# [202, 179, 233]

# %%
unique_label=loan_df["Property_Area"].unique()
count=[]
for i in unique_label:
    con=loan_df["Property_Area"]==i
    count.append(len(loan_df[con]))
count
# Out:
# [202, 179, 233]

# %%
a=pd.DataFrame(zip(unique_label,count),index=[1,2,3],columns=['Area','count'])
a
# Out:
#         Area  count
# 1      Urban    202
# 2      Rural    179
# 3  Semiurban    233

# %%
plt.figure(figsize=(10,6))
plt.bar('Area','count',data=a)
plt.xlabel('Area')
plt.ylabel('count')
plt.title('Bar Graph')
plt.savefig("output_csv")
plt.show()

# %%
plt.figure(figsize=(5,3))
l=loan_df["Property_Area"].value_counts().keys()
sns.countplot(data=loan_df,x='Property_Area',order=l)
plt.title('count plot')
plt.savefig("output_csv")
plt.show()

# %%
keys=loan_df['Property_Area'].value_counts().keys()
values=loan_df['Property_Area'].value_counts().values
plt.figure(figsize=(10,2))
plt.pie(values,
       labels=keys,
       autopct='%3f%%',
       explode=[0.1,0.1,0.1],
       startangle=180,
       radius=2)
plt.show()

# %%
d=dict(loan_df.dtypes)
num_col=[i for i in d if d[i]!='object']
num_cols
# Out:
# ['ApplicantIncome',
#  'CoapplicantIncome',
#  'LoanAmount',
#  'Loan_Amount_Term',
#  'Credit_History']

# %%
count=loan_df['ApplicantIncome'].count()
maxx=np.max(loan_df['ApplicantIncome'])
minn=np.min(loan_df['ApplicantIncome'])
mean=np.mean(loan_df['ApplicantIncome'])
median=np.median(loan_df['ApplicantIncome'])
std=np.std(loan_df['ApplicantIncome'])
p_25=np.percentile(loan_df['ApplicantIncome'],25)
p_50=np.percentile(loan_df['ApplicantIncome'],50)
p_75=np.percentile(loan_df['ApplicantIncome'],75)

# %%
l=[]
for i in num_cols:
    count=loan_df[i].count()
    maxx=np.max(loan_df[i])
    minn=np.min(loan_df[i])
    mean=np.mean(loan_df[i])
    median=np.median(loan_df[i])
    std=np.std(loan_df[i])
    p_25=np.percentile(loan_df[i],25)
    p_50=np.percentile(loan_df[i],50)
    p_75=np.percentile(loan_df[i],75)
    l.append([count,maxx,minn,mean,median,std,p_25,p_50,p_75])
    
loan_num_df=pd.DataFrame(zip(l[0],l[1],l[2],l[3],l[4]),index=['count','max','min','mean','median','std','25%','50%','75%'],columns=num_cols)
loan_num_df
# Out:
#         ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count        614.000000         614.000000  614.000000        614.000000
# max        81000.000000       41667.000000  700.000000        480.000000
# min          150.000000           0.000000    9.000000         12.000000
# mean        5403.459283        1621.245798  146.412162        342.410423
# median      3812.500000        1188.500000  129.000000        360.000000
# std         6104.064857        2923.864460   83.969005         64.376141
# 25%         2877.500000           0.000000  100.250000        360.000000
# 50%         3812.500000        1188.500000  129.000000        360.000000
# 75%         5795.000000        2297.250000  164.750000        360.000000
#
#         Credit_History
# count       614.000000
# max           1.000000
# min           0.000000
# mean          0.842199
# median        1.000000
# std           0.349396
# 25%           1.000000
# 50%           1.000000
# ...

# %%
plt.figure(figsize=(10,6))
plt.hist(loan_df['ApplicantIncome'],bins=40)
plt.xlabel("Applicant income")
plt.ylabel("count")
plt.show()

# %%
plt.boxplot(loan_df['ApplicantIncome'])
plt.show()

# %%
plt.subplot(3,3,1).hist(loan_df['ApplicantIncome'],bins=40)
plt.subplot(3,3,2).boxplot(loan_df['ApplicantIncome'])
plt.subplot(3,3,3).hist(loan_df['CoapplicantIncome'],bins=40)
plt.subplot(3,3,4).boxplot(loan_df['CoapplicantIncome'])
plt.subplot(3,3,5).hist(loan_df['LoanAmount'],bins=40)
plt.subplot(3,3,6).boxplot(loan_df['LoanAmount'])
plt.subplot(3,3,7).hist(loan_df['Loan_Amount_Term'],bins=40)
plt.subplot(3,3,8).boxplot(loan_df['Loan_Amount_Term'])
plt.subplot(3,3,9).hist(loan_df['Credit_History'],bins=40)
plt.show()

# %%
loan_df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
loan_cat_df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes          3      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#     Property_Area Loan_Status
# 0           Urban           Y
# 1           Rural           N
# 2           Urban           Y
# ...

# %%
loan_num_df
# Out:
#         ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count        614.000000         614.000000  614.000000        614.000000
# max        81000.000000       41667.000000  700.000000        480.000000
# min          150.000000           0.000000    9.000000         12.000000
# mean        5403.459283        1621.245798  146.412162        342.410423
# median      3812.500000        1188.500000  129.000000        360.000000
# std         6104.064857        2923.864460   83.969005         64.376141
# 25%         2877.500000           0.000000  100.250000        360.000000
# 50%         3812.500000        1188.500000  129.000000        360.000000
# 75%         5795.000000        2297.250000  164.750000        360.000000
#
#         Credit_History
# count       614.000000
# max           1.000000
# min           0.000000
# mean          0.842199
# median        1.000000
# std           0.349396
# 25%           1.000000
# 50%           1.000000
# ...

# %%
Q1=round(np.percentile(loan_df['ApplicantIncome'],25))
Q2=round(np.percentile(loan_df['ApplicantIncome'],50))
Q3=round(np.percentile(loan_df['ApplicantIncome'],75))
IQR=Q3-Q1
lb=Q1-(1.5*IQR)
ub=Q3+(1.5*IQR)
c1=loan_df['ApplicantIncome']<lb
c2=loan_df['ApplicantIncome']>ub
c=c1|c2
outliers=loan_df[c]

# %%
len(outliers)
# Out:
# 50

# %%
c3=loan_df['ApplicantIncome']>lb
c4=loan_df['ApplicantIncome']<ub
c=c3&c4
non_outliers=loan_df[c]

# %%
len(non_outliers)
# Out:
# 564

# %%
plt.figure(figsize=(10,6))
plt.hist(loan_df['ApplicantIncome'])
plt.hist(outliers['ApplicantIncome'])
plt.hist(non_outliers['ApplicantIncome'])
plt.show()

# %%
plt.boxplot(loan_df['ApplicantIncome'])
plt.boxplot(outliers['ApplicantIncome'])
plt.show()

# %%
lb
# Out:
# -1497.5

# %%
ub
# Out:
# 10170.5

# %%
l=[]
for i in loan_df['ApplicantIncome']:
    if i > ub:
        l.append(1)
    else:
        l.append(0)
loan_df['ApplicantIncome']=l

# %%
loan_df[['ApplicantIncome']].count()
# Out:
# ApplicantIncome    614
# dtype: int64

# %%
loan_df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes          3      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
loan_df['ApplicantIncome']=np.where(loan_df['ApplicantIncome']=='A','F',2)
loan_df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes          3      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#     ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
plt.hist(loan_df['ApplicantIncome'])
plt.show()

# %%
c0=loan_df['Gender']=='Female'
c1=loan_df['Gender']=='Male'
c2=loan_df['Loan_Status']=='Y'
c3=loan_df['Loan_Status']=="N"
m_a=c1&c2
m_r=c1&c3
f_a=c0&c2
f_r=c0&c3
loan_df[m_a]
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001002   Male      No          0      Graduate            No
# 2    LP001005   Male     Yes          0      Graduate           Yes
# 3    LP001006   Male     Yes          0  Not Graduate            No
# 4    LP001008   Male      No          0      Graduate            No
# 5    LP001011   Male     Yes          2      Graduate           Yes
# ..        ...    ...     ...        ...           ...           ...
# 607  LP002964   Male     Yes          2  Not Graduate            No
# 608  LP002974   Male     Yes          0      Graduate            No
# 610  LP002979   Male     Yes          3      Graduate            No
# 611  LP002983   Male     Yes          1      Graduate            No
# 612  LP002984   Male     Yes          2      Graduate            No
#
#     ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0                 2                0.0  146.412162             360.0
# ...

# %%
loan_df[m_r]
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 1    LP001003   Male     Yes          1      Graduate            No
# 7    LP001014   Male     Yes          3      Graduate            No
# 9    LP001020   Male     Yes          1      Graduate            No
# 13   LP001029   Male      No          0      Graduate            No
# 18   LP001038   Male     Yes          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 589  LP002926   Male     Yes          2      Graduate           Yes
# 591  LP002931   Male     Yes          2      Graduate           Yes
# 596  LP002941   Male     Yes          2  Not Graduate           Yes
# 597  LP002943   Male      No          2      Graduate            No
# 605  LP002960   Male     Yes          0  Not Graduate            No
#
#     ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1                 2             1508.0  128.000000             360.0
# ...

# %%
loan_df[f_a]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 29   LP001087  Female      No          2      Graduate            No
# 37   LP001112  Female     Yes          0      Graduate            No
# 45   LP001137  Female      No          0      Graduate            No
# 49   LP001151  Female      No          0      Graduate            No
# 50   LP001155  Female     Yes          0  Not Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 561  LP002813  Female     Yes          1      Graduate           Yes
# 582  LP002894  Female     Yes          0      Graduate            No
# 587  LP002917  Female      No          0  Not Graduate            No
# 604  LP002959  Female     Yes          1      Graduate            No
# 609  LP002978  Female      No          0      Graduate            No
#
#     ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
loan_df[f_r]
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 17   LP001036  Female      No          0      Graduate            No
# 48   LP001146  Female     Yes          0      Graduate            No
# 52   LP001164  Female      No          0      Graduate            No
# 54   LP001186  Female     Yes          1      Graduate           Yes
# 64   LP001222  Female      No          0      Graduate            No
# 69   LP001241  Female      No          0      Graduate            No
# 82   LP001267  Female     Yes          2      Graduate            No
# 136  LP001489  Female     Yes          0      Graduate            No
# 148  LP001519  Female      No          0      Graduate            No
# 166  LP001577  Female     Yes          0      Graduate            No
# 210  LP001708  Female      No          0      Graduate            No
# 251  LP001836  Female      No          2      Graduate            No
# 262  LP001870  Female      No          1      Graduate            No
# ...

# %%
print(len(loan_df[m_a]))
print(len(loan_df[m_r]))
print(len(loan_df[f_a]))
print(len(loan_df[f_r]))
# Out:
# 346
# 155
# 76
# 37

# %%
346+155+76+37
# Out:
# 614

# %%
len(loan_df)
# Out:
# 614

# %%
c=loan_df['Gender'].unique()
a_count=[]
r_count=[]
for i in c:
    c1=loan_df['Gender']==i
    c2=loan_df['Loan_Status']=='Y'
    c3=loan_df['Loan_Status']=='N'
    a_count.append(len(loan_df[c1&c2]))
    r_count.append(len(loan_df[c1&c3]))
a_count,r_count
# Out:
# ([346, 76], [155, 37])

# %%
b=pd.DataFrame(zip(a,a_count,r_count),columns=["Gender","Loan_accepted",'Loan_rejected'],index=[1,2])

# %%
import numpy as np

# %%
unique_label=loan_df["Property_Area"].unique()
count=[]
for i in unique_label:
    con=loan_df["Property_Area"]==i
    count.append(len(loan_df[con]))
count
# Out:
# [202, 179, 233]

# %%
a=pd.DataFrame(zip(unique_label,count),index=[1,2,3],columns=['Property area','count'])

# %%
a
# Out:
#   Property area  count
# 1         Urban    202
# 2         Rural    179
# 3     Semiurban    233

# %%
keys=loan_df['Property_Area'].value_counts().keys()
values=loan_df['Property_Area'].value_counts().values
plt.figure(figsize=(4,2))
plt.pie(values,
       labels=keys,
       autopct='%3ff%%',
       explode=[0.05,0.05,0.05],
       startangle=180,
       radius=2)
plt.show()

# %%
unique_label=loan_df["Property_Area"].unique()
count=[]
for i in unique_label:
    con=loan_df["Property_Area"]==i
    count.append(len(loan_df[con]))
count
# Out:
# [202, 179, 233]

# %%
a=pd.DataFrame(zip(unique_label,count),index=[1,2,3],columns=['Area','count'])

# %%
a
# Out:
#         Area  count
# 1      Urban    202
# 2      Rural    179
# 3  Semiurban    233

# %%
values=loan_df['Property_Area'].value_counts().values
keys=loan_df['Property_Area'].value_counts().keys()
plt.figure(figsize=(3,2))
plt.pie(values,
       labels=keys,
       autopct='%3f%%',
       explode=[0.05,0.05,0.05],
       startangle=180,
       radius=2)
plt.show()

# %%
a
# Out:
#         Area  count
# 1      Urban    202
# 2      Rural    179
# 3  Semiurban    233

# %%
plt.figure(figsize=(2,3))
plt.bar('Area','count',data=a)
plt.xlabel("area")
plt.ylabel("count")
plt.title("bargraph")
plt.show()

# %%
l=loan_df['Property_Area'].value_counts().keys()
sns.countplot(data=loan_df,x='Property_Area',order=l)
plt.show()

# %%
loan_df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes          3      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#     ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...
